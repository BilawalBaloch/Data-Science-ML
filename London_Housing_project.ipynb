# %% [markdown]
# <a href="https://colab.research.google.com/github/BilawalBaloch/Projects/blob/main/London_Housing_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("/content/London.csv")
df
# Out:
#       Unnamed: 0       Property Name    Price        House Type  \
# 0              0         Queens Road  1675000             House
# 1              1       Seward Street   650000  Flat / Apartment
# 2              2         Hotham Road   735000  Flat / Apartment
# 3              3        Festing Road  1765000             House
# 4              4        Spencer Walk   675000  Flat / Apartment
# ...          ...                 ...      ...               ...
# 3475        3475   One Lillie Square  3350000   New development
# 3476        3476  St. James's Street  5275000  Flat / Apartment
# 3477        3477       Ingram Avenue  5995000             House
# 3478        3478         Cork Street  6300000   New development
# 3479        3479    Courtenay Avenue  8650000             House
#
#       Area in sq ft  No. of Bedrooms  No. of Bathrooms  No. of Receptions  \
# 0              2716                5                 5                  5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3480 entries, 0 to 3479
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         3480 non-null   int64
#  1   Property Name      3480 non-null   object
#  2   Price              3480 non-null   int64
#  3   House Type         3480 non-null   object
#  4   Area in sq ft      3480 non-null   int64
#  5   No. of Bedrooms    3480 non-null   int64
#  6   No. of Bathrooms   3480 non-null   int64
#  7   No. of Receptions  3480 non-null   int64
#  8   Location           2518 non-null   object
#  9   City/County        3480 non-null   object
#  10  Postal Code        3480 non-null   object
# dtypes: int64(6), object(5)
# memory usage: 299.2+ KB

# %%
df.count()
# Out:
# Unnamed: 0           3480
# Property Name        3480
# Price                3480
# House Type           3480
# Area in sq ft        3480
# No. of Bedrooms      3480
# No. of Bathrooms     3480
# No. of Receptions    3480
# Location             2518
# City/County          3480
# Postal Code          3480
# dtype: int64

# %%
df.isnull()
# Out:
#       Unnamed: 0  Property Name  Price  House Type  Area in sq ft  \
# 0          False          False  False       False          False
# 1          False          False  False       False          False
# 2          False          False  False       False          False
# 3          False          False  False       False          False
# 4          False          False  False       False          False
# ...          ...            ...    ...         ...            ...
# 3475       False          False  False       False          False
# 3476       False          False  False       False          False
# 3477       False          False  False       False          False
# 3478       False          False  False       False          False
# 3479       False          False  False       False          False
#
#       No. of Bedrooms  No. of Bathrooms  No. of Receptions  Location  \
# 0               False             False              False     False
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0             0
# Property Name          0
# Price                  0
# House Type             0
# Area in sq ft          0
# No. of Bedrooms        0
# No. of Bathrooms       0
# No. of Receptions      0
# Location             962
# City/County            0
# Postal Code            0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.head(8)
# Out:
#    Unnamed: 0        Property Name    Price        House Type  Area in sq ft  \
# 0           0          Queens Road  1675000             House           2716
# 1           1        Seward Street   650000  Flat / Apartment            814
# 2           2          Hotham Road   735000  Flat / Apartment            761
# 3           3         Festing Road  1765000             House           1986
# 4           4         Spencer Walk   675000  Flat / Apartment            700
# 5           5  Craven Hill Gardens   420000  Flat / Apartment            403
# 6           6       Alfriston Road  1475000             House           1548
# 7           7         Bishops Gate   650000   New development            560
#
#    No. of Bedrooms  No. of Bathrooms  No. of Receptions     Location  \
# 0                5                 5                  5    Wimbledon
# 1                2                 2                  2  Clerkenwell
# ...

# %%
df.tail(11)
# Out:
#       Unnamed: 0       Property Name     Price        House Type  \
# 3469        3469    Hamilton Terrace   8250000             House
# 3470        3470         Clabon Mews   5700000             House
# 3471        3471    Herbert Crescent   4950000  Flat / Apartment
# 3472        3472    Chelsea Crescent   1750000  Flat / Apartment
# 3473        3473           Park Lane  19950000  Flat / Apartment
# 3474        3474        Queen's Gate   3500000         Penthouse
# 3475        3475   One Lillie Square   3350000   New development
# 3476        3476  St. James's Street   5275000  Flat / Apartment
# 3477        3477       Ingram Avenue   5995000             House
# 3478        3478         Cork Street   6300000   New development
# 3479        3479    Courtenay Avenue   8650000             House
#
#       Area in sq ft  No. of Bedrooms  No. of Bathrooms  No. of Receptions  \
# 3469           3940                5                 5                  5
# ...

# %%
df.loc[22:30]
# Out:
#     Unnamed: 0         Property Name    Price        House Type  \
# 22          22          The Draycott  8950000   New development
# 23          23  Campden Hill Gardens  1175000  Flat / Apartment
# 24          24         College Cross   550000  Flat / Apartment
# 25          25       St Mary's Grove  1300000             House
# 26          26     Goldhurst Terrace   800000  Flat / Apartment
# 27          27       Upper Park Road  3500000             House
# 28          28          Ditton Grove   374950   New development
# 29          29        Roymount Court   400000  Flat / Apartment
# 30          30        Wetherby House  1100000  Flat / Apartment
#
#     Area in sq ft  No. of Bedrooms  No. of Bathrooms  No. of Receptions  \
# 22           3154                4                 4                  4
# 23            765                2                 2                  2
# 24            479                1                 1                  1
# ...

# %%
df.iloc[88]
# Out:
# Unnamed: 0                       88
# Property Name            West Grove
# Price                        525000
# House Type                    House
# Area in sq ft                   829
# No. of Bedrooms                   2
# No. of Bathrooms                  2
# No. of Receptions                 2
# Location             Woodford Green
# City/County                   Essex
# Postal Code                 IG8 7NP
# Name: 88, dtype: object

# %%
df.dtypes
# Out:
# Unnamed: 0            int64
# Property Name        object
# Price                 int64
# House Type           object
# Area in sq ft         int64
# No. of Bedrooms       int64
# No. of Bathrooms      int64
# No. of Receptions     int64
# Location             object
# City/County          object
# Postal Code          object
# dtype: object

# %%
df.shape
# Out:
# (3480, 11)

# %%
df.Price
# Out:
# 0       1675000
# 1        650000
# 2        735000
# 3       1765000
# 4        675000
#          ...
# 3475    3350000
# 3476    5275000
# 3477    5995000
# 3478    6300000
# 3479    8650000
# Name: Price, Length: 3480, dtype: int64

# %%
df.Price.sum()
# Out:
# 6487320439

# %%
df.Location
# Out:
# 0                     Wimbledon
# 1                   Clerkenwell
# 2                        Putney
# 3                        Putney
# 4                        Putney
#                  ...
# 3475                        NaN
# 3476                 St James's
# 3477    Hampstead Garden Suburb
# 3478                    Mayfair
# 3479                   Highgate
# Name: Location, Length: 3480, dtype: object

# %%
plt.plot(df["City/County"], df["Price"], color="red")

# %%
plt.plot(df.index, df["Price"], color="g")

# %%
df.groupby("Area in sq ft")["average_price"].max()
# Out:
# Area in sq ft
# 274        299950.0
# 277        295000.0
# 292        398000.0
# 297        385000.0
# 302        350000.0
#             ...
# 12435    25000000.0
# 12526     7500000.0
# 12546     6000000.0
# 14358    17950000.0
# 15405    23950000.0
# Name: average_price, Length: 2034, dtype: float64

# %%
df.drop(["Postal Code"],axis=1,inplace=True)

# %%
df
# Out:
#       Unnamed: 0       Property Name    Price        House Type  \
# 0              0         Queens Road  1675000             House
# 1              1       Seward Street   650000  Flat / Apartment
# 2              2         Hotham Road   735000  Flat / Apartment
# 3              3        Festing Road  1765000             House
# 4              4        Spencer Walk   675000  Flat / Apartment
# ...          ...                 ...      ...               ...
# 3475        3475   One Lillie Square  3350000   New development
# 3476        3476  St. James's Street  5275000  Flat / Apartment
# 3477        3477       Ingram Avenue  5995000             House
# 3478        3478         Cork Street  6300000   New development
# 3479        3479    Courtenay Avenue  8650000             House
#
#       Area in sq ft  No. of Bedrooms  No. of Bathrooms  No. of Receptions  \
# 0              2716                5                 5                  5
# ...

# %%
df["No. of Receptions"] == 0
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3475    False
# 3476    False
# 3477    False
# 3478    False
# 3479    False
# Name: No. of Receptions, Length: 3480, dtype: bool

# %%
df["No. of Bathrooms"]==0
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3475    False
# 3476    False
# 3477    False
# 3478    False
# 3479    False
# Name: No. of Bathrooms, Length: 3480, dtype: bool

# %%
df["No. of Bedrooms"]==0
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3475    False
# 3476    False
# 3477    False
# 3478    False
# 3479    False
# Name: No. of Bedrooms, Length: 3480, dtype: bool

# %%
df["Area in sq ft"]==500
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3475    False
# 3476    False
# 3477    False
# 3478    False
# 3479    False
# Name: Area in sq ft, Length: 3480, dtype: bool

# %%
df["City/County"]=="London"
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 3475    False
# 3476     True
# 3477     True
# 3478     True
# 3479     True
# Name: City/County, Length: 3480, dtype: bool

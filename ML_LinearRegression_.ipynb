# %% [markdown]
# <a href="https://colab.research.google.com/github/BilawalBaloch/Projects/blob/main/ML_LinearRegression_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# prompt: import metricxs from sklearn rmse ,mse

from sklearn.metrics import mean_squared_error, r2_score

# %%
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.sample(10)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 484         1       1    male  25.0      1      0   91.0792        C   First
# 737         1       1    male  35.0      0      0  512.3292        C   First
# 67          0       3    male  19.0      0      0    8.1583        S   Third
# 28          1       3  female   NaN      0      0    7.8792        Q   Third
# 238         0       2    male  19.0      0      0   10.5000        S  Second
# 859         0       3    male   NaN      0      0    7.2292        C   Third
# 426         1       2  female  28.0      1      0   26.0000        S  Second
# 16          0       3    male   2.0      4      1   29.1250        Q   Third
# 360         0       3    male  40.0      1      4   27.9000        S   Third
# 673         1       2    male  31.0      0      0   13.0000        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# 484    man        True    B    Cherbourg   yes  False
# ...

# %%
df.shape
# Out:
# (891, 15)

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df['age']=df['age'].fillna(df['age'].mean(


))

# %%
df.isnull().sum(

)
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
X = df[['age']]
y = df['fare']

# %%
# prompt: import train test split

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train.shape
# Out:
# (623, 1)

# %%
X_train[0:10]
# Out:
#            age
# 445   4.000000
# 650  29.699118
# 172   1.000000
# 450  36.000000
# 314  43.000000
# 332  38.000000
# 801  31.000000
# 90   29.000000
# 834  18.000000
# 181  29.699118

# %%
X_test.shape
# Out:
# (268, 1)

# %%
X_test[0:10]
# Out:
#            age
# 709  29.699118
# 439  31.000000
# 840  20.000000
# 720   6.000000
# 39   14.000000
# 290  26.000000
# 300  29.699118
# 333  16.000000
# 208  16.000000
# 136  19.000000

# %%
y_train[0:10]
# Out:
# 445     81.8583
# 650      7.8958
# 172     11.1333
# 450     27.7500
# 314     26.2500
# 332    153.4625
# 801     26.2500
# 90       8.0500
# 834      8.3000
# 181     15.0500
# Name: fare, dtype: float64

# %%
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict (X_test)

# %%
# prompt: evaluate the model

from sklearn.metrics import mean_squared_error, r2_score

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean squared error:", mse)
print("R-squared:", r2)
# Out:
# Mean squared error: 2137.1021013378772
# R-squared: 0.009036430803225581

# %%
# prompt: save the model

import pickle

# Save the model to a file
with open('fare_prediction_model.sav', 'wb') as f:
  pickle.dump(model, f)

# %%
# prompt: plot the model

import matplotlib.pyplot as plt
plt.scatter(X_test, y_test,  color='black')
plt.plot(X_test, y_pred, color='blue', linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()

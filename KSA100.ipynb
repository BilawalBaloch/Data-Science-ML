# %% [markdown]
# <a href="https://colab.research.google.com/github/BilawalBaloch/Projects/blob/main/KSA100.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Pakistan Stock Exchange KSA100

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("/Stock Exchange KSE 100(Pakistan).csv")
df
# Out:
#            Date       Open       High        Low      Close   Change  \
# 0     23-Feb-21  31,722.16  31,800.90  31,597.31  31,626.19   -21.38
# 1     22-Feb-21  31,874.78  31,958.58  31,612.55  31,647.57  -203.61
# 2     19-Feb-21  31,748.75  31,904.30  31,749.43  31,851.18    91.36
# 3     18-Feb-21  32,049.85  32,104.67  31,745.72  31,759.82  -288.86
# 4     17-Feb-21  32,166.21  32,390.77  32,044.01  32,048.68   -93.15
# ...         ...        ...        ...        ...        ...      ...
# 3216  28-Feb-08  10,688.98  10,724.21  10,655.23  10,704.15    39.79
# 3217  27-Feb-08  10,670.68  10,732.92  10,623.36  10,664.36    -3.99
# 3218  26-Feb-08  10,596.40  10,668.35  10,578.01  10,668.35    79.51
# 3219  25-Feb-08  10,625.66  10,709.06  10,579.49  10,588.84   -18.45
# 3220  22-Feb-08  10,634.22  10,635.42  10,546.38  10,607.29        0
#
#            Volume
# 0     718,191,025
# 1     721,952,658
# 2     694,795,084
# 3     577,837,595
# 4     701,658,181
# ...           ...
# ...

# %%
df.to_string()
# Out:
# '           Date       Open       High        Low      Close     Change         Volume\n0     23-Feb-21  31,722.16  31,800.90  31,597.31  31,626.19     -21.38    718,191,025\n1     22-Feb-21  31,874.78  31,958.58  31,612.55  31,647.57    -203.61    721,952,658\n2     19-Feb-21  31,748.75  31,904.30  31,749.43  31,851.18      91.36    694,795,084\n3     18-Feb-21  32,049.85  32,104.67  31,745.72  31,759.82    -288.86    577,837,595\n4     17-Feb-21  32,166.21  32,390.77  32,044.01  32,048.68     -93.15    701,658,181\n5     16-Feb-21  31,898.51  32,155.42  31,891.80  32,141.83     250.03    514,044,525\n6     15-Feb-21  31,695.01  31,959.00  31,552.69  31,891.80     339.11    486,340,423\n7     12-Feb-21  31,703.25  31,819.14  31,517.21  31,552.69    -151.98    442,547,019\n8     11-Feb-21  32,121.31  32,255.15  31,653.40  31,704.67     -410.7  1,124,724,205\n9     10-Feb-21  32,186.99  32,234.98  31,949.20  32,115.37     -51.32  1,011,825,950\n10     9-Feb-21  32,275.59  32,365.63  3
# ...

# %%
df.head(10)
# Out:
#         Date       Open       High        Low      Close   Change  \
# 0  23-Feb-21  31,722.16  31,800.90  31,597.31  31,626.19   -21.38
# 1  22-Feb-21  31,874.78  31,958.58  31,612.55  31,647.57  -203.61
# 2  19-Feb-21  31,748.75  31,904.30  31,749.43  31,851.18    91.36
# 3  18-Feb-21  32,049.85  32,104.67  31,745.72  31,759.82  -288.86
# 4  17-Feb-21  32,166.21  32,390.77  32,044.01  32,048.68   -93.15
# 5  16-Feb-21  31,898.51  32,155.42  31,891.80  32,141.83   250.03
# 6  15-Feb-21  31,695.01  31,959.00  31,552.69  31,891.80   339.11
# 7  12-Feb-21  31,703.25  31,819.14  31,517.21  31,552.69  -151.98
# 8  11-Feb-21  32,121.31  32,255.15  31,653.40  31,704.67   -410.7
# 9  10-Feb-21  32,186.99  32,234.98  31,949.20  32,115.37   -51.32
#
#           Volume
# 0    718,191,025
# 1    721,952,658
# 2    694,795,084
# 3    577,837,595
# 4    701,658,181
# 5    514,044,525
# 6    486,340,423
# 7    442,547,019
# 8  1,124,724,205
# 9  1,011,825,950
# ...

# %%
df.tail(7)
# Out:
#            Date       Open       High        Low      Close  Change  \
# 3214   3-Mar-08  10,658.04  10,663.51  10,501.10  10,554.05  -81.64
# 3215  29-Feb-08  10,726.05  10,750.60  10,618.88  10,635.69  -68.46
# 3216  28-Feb-08  10,688.98  10,724.21  10,655.23  10,704.15   39.79
# 3217  27-Feb-08  10,670.68  10,732.92  10,623.36  10,664.36   -3.99
# 3218  26-Feb-08  10,596.40  10,668.35  10,578.01  10,668.35   79.51
# 3219  25-Feb-08  10,625.66  10,709.06  10,579.49  10,588.84  -18.45
# 3220  22-Feb-08  10,634.22  10,635.42  10,546.38  10,607.29       0
#
#            Volume
# 3214  196,083,664
# 3215  335,109,824
# 3216  325,539,584
# 3217  396,419,776
# 3218  265,668,784
# 3219  273,149,184
# 3220  313,082,688
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# ...

# %%
df.describe()
# Out:
#              Date       Open       High       Low     Close Change  \
# count        3221       3221       3221      3221      3221   3221
# unique       3221       3213       3215      3211      3209   3104
# top     23-Feb-21  29,269.00  24,777.37  6,639.00  6,639.25      0
# freq            1          2          2         3         3      5
#
#              Volume
# count          3221
# unique         3220
# top     302,831,072
# freq              2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3221 entries, 0 to 3220
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3221 non-null   object
#  1   Open    3221 non-null   object
#  2   High    3221 non-null   object
#  3   Low     3221 non-null   object
#  4   Close   3221 non-null   object
#  5   Change  3221 non-null   object
#  6   Volume  3221 non-null   object
# dtypes: object(7)
# memory usage: 176.3+ KB

# %%
df.shape
# Out:
# (3221, 7)

# %%
df.isnull().sum()
# Out:
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# Change    0
# Volume    0
# dtype: int64

# %%
df.Close
# Out:
# 0       31,626.19
# 1       31,647.57
# 2       31,851.18
# 3       31,759.82
# 4       32,048.68
#           ...
# 3216    10,704.15
# 3217    10,664.36
# 3218    10,668.35
# 3219    10,588.84
# 3220    10,607.29
# Name: Close, Length: 3221, dtype: object

# %%
df.High
# Out:
# 0       31,800.90
# 1       31,958.58
# 2       31,904.30
# 3       32,104.67
# 4       32,390.77
#           ...
# 3216    10,724.21
# 3217    10,732.92
# 3218    10,668.35
# 3219    10,709.06
# 3220    10,635.42
# Name: High, Length: 3221, dtype: object

# %%
df.Low
# Out:
# 0       31,597.31
# 1       31,612.55
# 2       31,749.43
# 3       31,745.72
# 4       32,044.01
#           ...
# 3216    10,655.23
# 3217    10,623.36
# 3218    10,578.01
# 3219    10,579.49
# 3220    10,546.38
# Name: Low, Length: 3221, dtype: object

# %%
df["Date"]
# Out:
# 0       23-Feb-21
# 1       22-Feb-21
# 2       19-Feb-21
# 3       18-Feb-21
# 4       17-Feb-21
#           ...
# 3216    28-Feb-08
# 3217    27-Feb-08
# 3218    26-Feb-08
# 3219    25-Feb-08
# 3220    22-Feb-08
# Name: Date, Length: 3221, dtype: object

# %%
df.Change
# Out:
# 0        -21.38
# 1       -203.61
# 2         91.36
# 3       -288.86
# 4        -93.15
#          ...
# 3216      39.79
# 3217      -3.99
# 3218      79.51
# 3219     -18.45
# 3220          0
# Name: Change, Length: 3221, dtype: object

# %%
df.loc[1:33]
# Out:
#          Date       Open       High        Low      Close   Change  \
# 1   22-Feb-21  31,874.78  31,958.58  31,612.55  31,647.57  -203.61
# 2   19-Feb-21  31,748.75  31,904.30  31,749.43  31,851.18    91.36
# 3   18-Feb-21  32,049.85  32,104.67  31,745.72  31,759.82  -288.86
# 4   17-Feb-21  32,166.21  32,390.77  32,044.01  32,048.68   -93.15
# 5   16-Feb-21  31,898.51  32,155.42  31,891.80  32,141.83   250.03
# 6   15-Feb-21  31,695.01  31,959.00  31,552.69  31,891.80   339.11
# 7   12-Feb-21  31,703.25  31,819.14  31,517.21  31,552.69  -151.98
# 8   11-Feb-21  32,121.31  32,255.15  31,653.40  31,704.67   -410.7
# 9   10-Feb-21  32,186.99  32,234.98  31,949.20  32,115.37   -51.32
# 10   9-Feb-21  32,275.59  32,365.63  32,149.63  32,166.69   -80.25
# 11   8-Feb-21  32,393.94  32,478.42  32,185.62  32,246.94  -139.15
# 12   4-Feb-21  32,358.58  32,602.03  32,302.37  32,386.09    27.13
# 13   3-Feb-21  32,187.71  32,451.23  32,167.97  32,358.96   190.99
# ...

# %%
df.iloc[88]
# Out:
# Date        19-Oct-20
# Open        28,480.74
# High        28,648.06
# Low         28,437.03
# Close       28,567.79
# Change             96
# Volume    319,531,161
# Name: 88, dtype: object

# %%
# Extract the data from the DataFrame
high_values = data_to_plot["High"].to_numpy()
low_values = data_to_plot["Low"].to_numpy()
change_values = data_to_plot["Change"].to_numpy()

# Plot the data
plt.plot(high_values, label="High")
plt.plot(low_values, label="Low")
plt.plot(change_values, label="Change")

# Add labels and

# %%
plt.plot(high_values, label="High")

# %% [markdown]
# #BCZ Data is in such a huge valume , all the other Graphical work are done in Tableau , which is also avaliable on github
